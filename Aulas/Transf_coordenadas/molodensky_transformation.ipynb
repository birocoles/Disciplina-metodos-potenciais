# %% [markdown]
# # Transformação de coordenadas geodésicas

# %% [markdown]
# A posição de um ponto localizado sobre a superfície da Terra ou próximo a ela é comumente definida em coordenadas geodésicas, que são referidas a um elipsóide de revolução. Um elipsoide de revolução pode ser definido por meio da rotação de uma elipse (Figura 1) em torno de seu semieixo menor $b$.

# %%
from IPython.display import Image

# %%
Image('elipse_semieixos_ab.png', width=600)

# %% [markdown]
# **Figura 1:** *Elipse com semieixo maior $a$ e semieixo menor $b$. Esta elipse possui a origem $O$ coincidente com o centro de massa da Terra e o semieixo menor $b$ coincidente com o eixo de rotação médio da Terra.*

# %%
Image('coordenadas_geodesicas.png', width=600)

# %% [markdown]
# **Figura 2:** *bla bla bla*

# %% [markdown]
# # Transformação de coordenadas geodésicas

# %% [markdown]
# Em geociências, a posição de um ponto localizado sobre a superfície da Terra ou próximo a ela é comumente definida em coordenadas geodésicas. Geralmente, coordenadas geodésicas são definidas em relação a um elipsóide de revolução com origem no centro de massa da Terra ou em um ponto próximo a este. Um elipsoide de revolução

# %%
from IPython.display import Image

# %%
Image('elipse_semieixos_ab.png')
